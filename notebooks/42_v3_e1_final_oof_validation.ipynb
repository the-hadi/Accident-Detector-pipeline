# %% [markdown]
# # V3 — E1-AND final fold-safe OOF validation
#
# This notebook validates the E1 AND ensemble without decoding MP4 files or retraining A2/D1. In each outer fold, thresholds are selected only from its 48 inner-validation videos and are then evaluated on 120 untouched outer-validation videos.
#
# Accuracy is the primary metric for this experiment. The safety-constrained variant is retained to show the Recall trade-off.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SCRIPTS = PROJECT_ROOT / 'scripts'
if str(SCRIPTS) not in sys.path:
    sys.path.insert(0, str(SCRIPTS))

from v3_e1_final_oof_ensemble import run

result = run()
result

# %%
import pandas as pd
from IPython.display import display, Image

REPORT_ROOT = Path(r'P:\NexarCollisionData\reports_v3')
comparison = pd.read_csv(REPORT_ROOT / 'e1_final_oof_accuracy_comparison.csv')
display(comparison)
Image(filename=str(REPORT_ROOT / 'e1_final_oof_accuracy_comparison.png'))

# %% [markdown]
# ## Decision rule
#
# E1 can replace D1 only if its fold-safe OOF improvement is stable and compatible with the intended Recall requirement. A marginal Accuracy gain with a statistically non-significant paired comparison or low Recall is documented, but not promoted to the default deployable model.
