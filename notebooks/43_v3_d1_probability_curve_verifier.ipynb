# %% [markdown]
# # V3 — D1 probability-curve verifier
#
# Fast no-new-video experiment: use only the sequence of D1 window probabilities, fit the verifier inside each outer fold's 48-video inner partition, and evaluate it once on that fold's 120 untouched videos.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SCRIPTS = PROJECT_ROOT / 'scripts'
if str(SCRIPTS) not in sys.path:
    sys.path.insert(0, str(SCRIPTS))

from v3_d1_curve_verifier import run
result = run()
result

# %%
import pandas as pd
from IPython.display import display, Image

REPORT_ROOT = Path(r'P:\NexarCollisionData\reports_v3')
display(pd.read_csv(REPORT_ROOT / 'd1_curve_verifier_comparison.csv'))
Image(filename=str(REPORT_ROOT / 'd1_curve_verifier_chart.png'))

# %% [markdown]
# The verifier is promoted only if it improves fold-safe OOF Accuracy while keeping Recall at least 85%. Otherwise D1 remains the deployable model.
