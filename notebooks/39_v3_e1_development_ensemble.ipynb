# %% [markdown]
# # V3-9 — E1 development diagnostic: A2-MP + D1
#
# This notebook is deliberately cheap and non-learned. It uses existing full-MP4 predictions only. It is not a final OOF ensemble, does not calibrate probabilities, and does not choose a final threshold.

# %%
from __future__ import annotations
from pathlib import Path
import json
import sys
from IPython.display import display

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT / 'scripts') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'scripts'))

from v3_e1_development_ensemble import context_report, run_diagnostic

RUN_DIAGNOSTIC = True
print(context_report())

# %%
# Uses stored A2-MP and D1 video-level predictions; no MP4 opens or model training.
if RUN_DIAGNOSTIC:
    result = run_diagnostic()
    print(json.dumps(result['summary'], ensure_ascii=False, indent=2))
    display(result['comparison'])
else:
    print('Set RUN_DIAGNOSTIC=True to regenerate the non-learned diagnostic.')

# %% [markdown]
# Interpretation: any apparent gain here is development-only. A final E1 claim requires the fold-local OOF process in `e1_ensemble_pipeline.md`.
